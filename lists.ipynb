# %%
grades = [15, 18, 12, 20, 16]
print("Original list:", grades)
# Out:
# Original list: [15, 18, 12, 20, 16]

# %%
grades.append(17)
print("After append:", grades)
# Out:
# After append: [15, 18, 12, 20, 16, 17]
